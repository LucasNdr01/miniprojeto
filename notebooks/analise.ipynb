# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../dados/base_varejo_limpa.csv', sep=';')
df.head()
# Out:
#          DATA  CO_ID  CL_ID CL_GENERO  CL_EC  CL_FHL CL_SEG  PR_ID     PR_CAT  \
# 0  2019-02-01   1000    534         M      4       1      C     67    Bebidas
# 1  2019-02-01   1000    534         M      4       1      C     70    Bebidas
# 2  2019-02-01   1000    534         M      4       1      C    178    Higiene
# 3  2019-02-01   1000    534         M      4       1      C      4  Alimentos
# 4  2019-02-01   1000    534         M      4       1      C    175    Limpeza
#
#                 PR_NOME
# 0  Refrigerante Guarana
# 1   Refrigerante Outros
# 2       Lenco Umedecido
# 3               Abacaxi
# 4     Limpador Multiuso

# %%
df['CL_FHL'].describe()
df['CL_FHL'].value_counts()
# Out:
# CL_FHL
# 0    384986
# 2     94168
# 3     92407
# 1     90845
# 4     71041
# Name: count, dtype: int64

# %%
df.groupby('PR_CAT')['CL_GENERO'].size().sort_values(ascending=False)
# Out:
# PR_CAT
# Alimentos        384197
# Higiene          137702
# Limpeza          128632
# Bebidas           38264
# Pet               28553
# Acessorios        12871
# Sem Categoria      3228
# Name: CL_GENERO, dtype: int64
